# %%
import pandas as pd

data = pd.read_excel('Data Sampah.xlsx')

df = pd.DataFrame({
    'Kode Provinsi': data['kode_provinsi'],
    'Nama Provinsi': data['nama_provinsi'],  
    'Kode Kabupaten Kota': data['kode_kabupaten_kota'],
    'Nama Kabupaten Kota' : data['nama_kabupaten_kota'],
    'Jumlah Produksi Sampah' : data['jumlah_produksi_sampah'],
    'Satuan (Ton)' : data['satuan'],
    'Tahun' : data['tahun']
})
df.index = df.index + 1
print(df)
# Out:
# <bound method NDFrame.head of      Kode Provinsi Nama Provinsi  Kode Kabupaten Kota  \
# 1               32    JAWA BARAT                 3201
# 2               32    JAWA BARAT                 3202
# 3               32    JAWA BARAT                 3203
# 4               32    JAWA BARAT                 3204
# 5               32    JAWA BARAT                 3205
# 6               32    JAWA BARAT                 3206
# 7               32    JAWA BARAT                 3207
# 8               32    JAWA BARAT                 3208
# 9               32    JAWA BARAT                 3209
# 10              32    JAWA BARAT                 3210
# 11              32    JAWA BARAT                 3211
# 12              32    JAWA BARAT                 3212
# 13              32    JAWA BARAT                 3213
# 14              32    JAWA BARAT                 3214
# 15              32    JAWA BARAT                 3215
# 16              32    JAWA BARAT                 3216
# ...

# %%
tahun_tertentu = 2019
jawa_barat_data = df[(df['Nama Provinsi'] == 'Jawa Barat') & (df['Tahun'] == tahun_tertentu)]
total_produksi_sampah = jawa_barat_data['Jumlah Produksi Sampah'].sum()
print(f"Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun {tahun_tertentu} adalah {total_produksi_sampah} Ton.")
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2019 adalah 0.0 Ton.

# %%
total_per_tahun = df.groupby('Tahun')['Jumlah Produksi Sampah'].sum()

print("Total produksi sampah per tahun:")
print(total_per_tahun)
# Out:
# Total produksi sampah per tahun:
# Tahun
# 2015    20969.27
# 2016    20969.27
# 2017    20969.27
# 2018    22772.92
# 2019    24490.56
# 2020    25333.00
# 2021    15735.36
# 2022        0.00
# 2023        0.00
# Name: Jumlah Produksi Sampah, dtype: float64

# %%
total_per_kota_per_tahun = df.groupby(['Nama Kabupaten Kota', 'Tahun'])['Jumlah Produksi Sampah'].sum()
total_per_kota_per_tahun = total_per_kota_per_tahun.reset_index()
print("Total produksi sampah per Kota/Kabupaten per tahun:")
print(total_per_kota_per_tahun)
# Out:
# Total produksi sampah per Kota/Kabupaten per tahun:
#          Nama Kabupaten Kota  Tahun  Jumlah Produksi Sampah
# 0          KABUPATEN BANDUNG   2015                 1895.94
# 1          KABUPATEN BANDUNG   2016                 1895.94
# 2          KABUPATEN BANDUNG   2017                 1895.94
# 3          KABUPATEN BANDUNG   2018                 2068.06
# 4          KABUPATEN BANDUNG   2019                 1334.12
# 5          KABUPATEN BANDUNG   2020                 1355.00
# 6          KABUPATEN BANDUNG   2021                 1489.04
# 7          KABUPATEN BANDUNG   2022                    0.00
# 8          KABUPATEN BANDUNG   2023                    0.00
# 9    KABUPATEN BANDUNG BARAT   2015                  616.08
# 10   KABUPATEN BANDUNG BARAT   2016                  616.08
# 11   KABUPATEN BANDUNG BARAT   2017                  616.08
# 12   KABUPATEN BANDUNG BARAT   2018                  663.54
# 13   KABUPATEN BANDUNG BARAT   2019                 1124.50
# ...

# %%
df.head(10)
# Out:
#     Kode Provinsi Nama Provinsi  Kode Kabupaten Kota    Nama Kabupaten Kota  \
# 1              32    JAWA BARAT                 3201        KABUPATEN BOGOR
# 2              32    JAWA BARAT                 3202     KABUPATEN SUKABUMI
# 3              32    JAWA BARAT                 3203      KABUPATEN CIANJUR
# 4              32    JAWA BARAT                 3204      KABUPATEN BANDUNG
# 5              32    JAWA BARAT                 3205        KABUPATEN GARUT
# 6              32    JAWA BARAT                 3206  KABUPATEN TASIKMALAYA
# 7              32    JAWA BARAT                 3207       KABUPATEN CIAMIS
# 8              32    JAWA BARAT                 3208     KABUPATEN KUNINGAN
# 9              32    JAWA BARAT                 3209      KABUPATEN CIREBON
# 10             32    JAWA BARAT                 3210   KABUPATEN MAJALENGKA
#
#     Jumlah Produksi Sampah  Satuan (Ton)  Tahun
# 1                  1511.15  TON PER HARI   2015
# ...

# %%
df.head()
# Out:
#    Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    Jumlah Produksi Sampah  Satuan (Ton)  Tahun
# 1                 1511.15  TON PER HARI   2015
# 2                  419.01  TON PER HARI   2015
# 3                  981.41  TON PER HARI   2015
# 4                 1895.94  TON PER HARI   2015
# 5                  464.74  TON PER HARI   2015

# %%
df.tail()
# Out:
#      Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 239             32    JAWA BARAT                 3275         KOTA BEKASI
# 240             32    JAWA BARAT                 3276          KOTA DEPOK
# 241             32    JAWA BARAT                 3277         KOTA CIMAHI
# 242             32    JAWA BARAT                 3278    KOTA TASIKMALAYA
# 243             32    JAWA BARAT                 3279         KOTA BANJAR
#
#      Jumlah Produksi Sampah  Satuan (Ton)  Tahun
# 239                     NaN  TON PER HARI   2023
# 240                     NaN  TON PER HARI   2023
# 241                     NaN  TON PER HARI   2023
# 242                     NaN  TON PER HARI   2023
# 243                     NaN  TON PER HARI   2023

# %%
df.sample()
# Out:
#     Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 47             32    JAWA BARAT                 3272       KOTA SUKABUMI
#
#     Jumlah Produksi Sampah  Satuan (Ton)  Tahun
# 47                  309.91  TON PER HARI   2016

# %%
df
# Out:
#      Kode Provinsi Nama Provinsi  Kode Kabupaten Kota  \
# 1               32    JAWA BARAT                 3201
# 2               32    JAWA BARAT                 3202
# 3               32    JAWA BARAT                 3203
# 4               32    JAWA BARAT                 3204
# 5               32    JAWA BARAT                 3205
# 6               32    JAWA BARAT                 3206
# 7               32    JAWA BARAT                 3207
# 8               32    JAWA BARAT                 3208
# 9               32    JAWA BARAT                 3209
# 10              32    JAWA BARAT                 3210
# 11              32    JAWA BARAT                 3211
# 12              32    JAWA BARAT                 3212
# 13              32    JAWA BARAT                 3213
# 14              32    JAWA BARAT                 3214
# 15              32    JAWA BARAT                 3215
# 16              32    JAWA BARAT                 3216
# ...

# %%
df.count()
# Out:
# Kode Provinsi             243
# Nama Provinsi             243
# Kode Kabupaten Kota       243
# Nama Kabupaten Kota       243
# Jumlah Produksi Sampah    189
# Satuan (Ton)              243
# Tahun                     243
# dtype: int64

# %%
df.shape
# Out:
# (243, 7)

# %%
df.dtypes
# Out:
# Kode Provinsi               int64
# Nama Provinsi              object
# Kode Kabupaten Kota         int64
# Nama Kabupaten Kota        object
# Jumlah Produksi Sampah    float64
# Satuan (Ton)               object
# Tahun                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 1 to 243
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Kode Provinsi           243 non-null    int64
#  1   Nama Provinsi           243 non-null    object
#  2   Kode Kabupaten Kota     243 non-null    int64
#  3   Nama Kabupaten Kota     243 non-null    object
#  4   Jumlah Produksi Sampah  189 non-null    float64
#  5   Satuan (Ton)            243 non-null    object
#  6   Tahun                   243 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 13.4+ KB

# %%
df.describe(include='all')
# Out:
#         Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# count           243.0           243           243.000000                 243
# unique            NaN             1                  NaN                  27
# top               NaN    JAWA BARAT                  NaN     KABUPATEN BOGOR
# freq              NaN           243                  NaN                   9
# mean             32.0           NaN          3231.333333                 NaN
# std               0.0           NaN            31.266252                 NaN
# min              32.0           NaN          3201.000000                 NaN
# 25%              32.0           NaN          3207.000000                 NaN
# 50%              32.0           NaN          3214.000000                 NaN
# 75%              32.0           NaN          3273.000000                 NaN
# max              32.0           NaN          3279.000000                 NaN
#
# ...
